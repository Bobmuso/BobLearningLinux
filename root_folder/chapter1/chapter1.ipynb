# %% [markdown]
# Linux is used in a variaty of industries, the talent demand outweighs the skill availability
#
# The linux expirience might encompass, configuring systems, running servers and outher proccesess. Due to ongoning developments this learning journey is going to be a lengthy one.

# %% [markdown]
# Linux is the kernel, the whole system is GNU/Linux since open source equivalent of UNIX commands are used.
