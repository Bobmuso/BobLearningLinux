# %% [markdown]
# 1
# Linux is used in a variaty of industries, the talent demand outweighs the skill availability
#
# The linux expirience might encompass, configuring systems, running servers and other proccesess. Due to ongoning developments this learning journey is going to be a lengthy one.

# %% [markdown]
# 2
# Linux is the kernel which is the core of the system, the whole system is GNU/Linux since open source equivalent of UNIX commands are used.

# %% [markdown]
# 3
# Befor linux, it started with UNIX, developed at T&T Bell Labs in the 1970s, it was writen in C which made it portable since other software only worked with specific hardware.
# UNIX is now owned by Open Group. softwares that call themselves UNIX are first certified

# %% [markdown]
# 4
# Linus Torvalds, linux started as an open source alternative to minix in frustration with it's licencing in 1997
#
# Linux is now a dominant software but since it has not ben certified it's UNIX like

# %% [markdown]
# 5
# Richard Stallman, GNU project in 1983.initialy the focused on building their own os but then shifted to building tools that make the os usable

# %% [markdown]
# 6
# linux is open source, the source programming code is open. this means user are free to see what makes the code work as well as reverse engineer it.
#
# linux also comes with many distributions these differnet packages that come with the kernel

# %% [markdown]
# 7
# linux embraces the CLI unlike other OSs which tend to shield the users from the cli, in order to prevent damages
