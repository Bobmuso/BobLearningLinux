# %% [markdown]
# In this lesson I learned that this "sysadmin@localhost:~$" is called a cli prompt or a shell prompt
#
# Promt tells us that the user is called sysadmin, but in your terminal it might display something completely differnet.
#
# after the ":" a command could be enterd
#
# an example below:

# %%
ls
# Out:
# lesson1.ipynb

# %% [markdown]
# running it shows the files and folders with in your directory
